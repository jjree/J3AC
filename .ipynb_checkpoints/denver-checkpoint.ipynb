# %%
# Dependencies
from splinter import Browser
from bs4 import BeautifulSoup as bs
from sqlalchemy import create_engine
import numpy as np
import pandas as pd
import requests
import pymongo
from datetime import datetime
import time

# %%
file = "data/Denver/crime.csv"
data1 = pd.read_csv(file)

# %%
# INCIDENT_ID	OFFENSE_ID	OFFENSE_CODE	OFFENSE_CODE_EXTENSION	OFFENSE_TYPE_ID	OFFENSE_CATEGORY_ID	FIRST_OCCURRENCE_DATE	
# LAST_OCCURRENCE_DATE	REPORTED_DATE	INCIDENT_ADDRESS	GEO_X	GEO_Y	GEO_LON	GEO_LAT	DISTRICT_ID	PRECINCT_ID	NEIGHBORHOOD_ID	IS_CRIME	IS_TRAFFIC
data = data1[["INCIDENT_ID", "FIRST_OCCURRENCE_DATE", "OFFENSE_TYPE_ID", "OFFENSE_CATEGORY_ID", "GEO_LAT", "GEO_LON"]].copy()
data
# Out:
#         INCIDENT_ID   FIRST_OCCURRENCE_DATE               OFFENSE_TYPE_ID  \
# 0        2016376978   6/15/2016 11:31:00 PM  weapon-unlawful-discharge-of
# 1       20186000994  10/11/2017 12:30:00 PM                   theft-other
# 2       20166003953     3/4/2016 8:00:00 PM      theft-items-from-vehicle
# 3         201872333    1/30/2018 7:20:00 PM                   theft-other
# 4        2017411405    6/22/2017 8:53:00 PM                theft-shoplift
# ...             ...                     ...                           ...
# 508722   2018836985   12/11/2018 6:06:00 PM                    traf-other
# 508723  20188058998   11/19/2018 4:00:00 PM    theft-fail-return-rent-veh
# 508724   2018848306   12/16/2018 5:37:00 PM              traffic-accident
# 508725   2018831000    12/9/2018 5:21:00 AM                    traf-other
# 508726  20186012081   12/12/2018 4:35:00 PM      theft-parts-from-vehicle
#
#              OFFENSE_CATEGORY_ID    GEO_LAT     GEO_LON
# 0               all-other-crimes  39.773188 -104.809881
# 1                        larceny  39.785649 -104.781434
# 2       theft-from-motor-vehicle  39.663490 -104.957381
# 3                        larceny  39.702698 -104.941440
# 4                        larceny  39.717107 -104.955370
# ...                          ...        ...         ...
# 508722          all-other-crimes  39.739862 -104.948043
# 508723        white-collar-crime  39.836210 -104.697230
# 508724          traffic-accident  39.687491 -104.940655
# 508725          all-other-crimes  39.738855 -105.029758
# 508726  theft-from-motor-vehicle  39.678211 -104.937077
#
# [508727 rows x 6 columns]

# %%
dates = []
years = []

for date in data["FIRST_OCCURRENCE_DATE"]:
    date = datetime.strptime(date, "%m/%d/%Y %I:%M:%S %p")
    dates.append(date)
    years.append(date.year)
    
data["date"] = dates
data["years"] = years
data
# Out:
#         INCIDENT_ID   FIRST_OCCURRENCE_DATE               OFFENSE_TYPE_ID  \
# 0        2016376978   6/15/2016 11:31:00 PM  weapon-unlawful-discharge-of
# 1       20186000994  10/11/2017 12:30:00 PM                   theft-other
# 2       20166003953     3/4/2016 8:00:00 PM      theft-items-from-vehicle
# 3         201872333    1/30/2018 7:20:00 PM                   theft-other
# 4        2017411405    6/22/2017 8:53:00 PM                theft-shoplift
# ...             ...                     ...                           ...
# 508722   2018836985   12/11/2018 6:06:00 PM                    traf-other
# 508723  20188058998   11/19/2018 4:00:00 PM    theft-fail-return-rent-veh
# 508724   2018848306   12/16/2018 5:37:00 PM              traffic-accident
# 508725   2018831000    12/9/2018 5:21:00 AM                    traf-other
# 508726  20186012081   12/12/2018 4:35:00 PM      theft-parts-from-vehicle
#
#              OFFENSE_CATEGORY_ID    GEO_LAT     GEO_LON                date  \
# 0               all-other-crimes  39.773188 -104.809881 2016-06-15 23:31:00
# 1                        larceny  39.785649 -104.781434 2017-10-11 12:30:00
# 2       theft-from-motor-vehicle  39.663490 -104.957381 2016-03-04 20:00:00
# 3                        larceny  39.702698 -104.941440 2018-01-30 19:20:00
# 4                        larceny  39.717107 -104.955370 2017-06-22 20:53:00
# ...                          ...        ...         ...                 ...
# 508722          all-other-crimes  39.739862 -104.948043 2018-12-11 18:06:00
# 508723        white-collar-crime  39.836210 -104.697230 2018-11-19 16:00:00
# 508724          traffic-accident  39.687491 -104.940655 2018-12-16 17:37:00
# 508725          all-other-crimes  39.738855 -105.029758 2018-12-09 05:21:00
# 508726  theft-from-motor-vehicle  39.678211 -104.937077 2018-12-12 16:35:00
#
#         years
# 0        2016
# 1        2017
# 2        2016
# 3        2018
# 4        2017
# ...       ...
# 508722   2018
# 508723   2018
# 508724   2018
# 508725   2018
# 508726   2018
#
# [508727 rows x 8 columns]

# %%
print(type(data["years"][0]))
data

# %%
data_2014 = pd.DataFrame()
data_2015 = pd.DataFrame()
data_2016 = pd.DataFrame()
data_2017 = pd.DataFrame()
data_2018 = pd.DataFrame()

data_2014 = data.loc[data["years"] == 2014]
print(data_2014)
data_2015 = data.loc[data["years"] == 2015]
print(data_2015)
data_2016 = data.loc[data["years"] == 2016]
print(data_2016)
data_2017 = data.loc[data["years"] == 2017]
print(data_2017)
data_2018 = data.loc[data["years"] == 2018]
data_2018
# Out:
#         INCIDENT_ID   FIRST_OCCURRENCE_DATE       OFFENSE_TYPE_ID  \
# 408       201871332  12/19/2014 12:00:00 PM        theft-embezzle
# 11512    2018137970   12/1/2014 12:00:00 AM     sex-aslt-non-rape
# 12722    2018107649    2/13/2014 9:24:00 PM  criminal-trespassing
# 18979    2014478770   9/10/2014 11:08:00 AM      traffic-accident
# 21913    2018345525     5/1/2014 1:00:00 PM        assault-simple
# ...             ...                     ...                   ...
# 474713  20176011247  11/19/2014 12:25:00 PM  fraud-identity-theft
# 483431   2018553995     8/7/2014 8:45:00 PM     threats-to-injure
# 487237   2018776994    4/17/2014 6:00:00 PM         sex-aslt-rape
# 493148   2018718756    9/24/2014 1:23:00 PM        forgery-checks
# 502702   2018669371    5/1/2014 12:00:00 AM     sex-aslt-non-rape
#
#                  OFFENSE_CATEGORY_ID    GEO_LAT     GEO_LON  \
# 408               white-collar-crime  39.823944 -104.770129
# 11512                 sexual-assault        NaN         NaN
# 12722               all-other-crimes  39.694575 -104.989849
# 18979               traffic-accident  39.674578 -104.973130
# 21913   other-crimes-against-persons  39.681391 -104.958938
# ...                              ...        ...         ...
# 474713            white-collar-crime  39.759371 -104.923136
# 483431               public-disorder  39.737273 -104.997084
# 487237                sexual-assault        NaN         NaN
# 493148            white-collar-crime  39.749824 -104.973709
# 502702                sexual-assault        NaN         NaN
#
#                       date  years
# 408    2014-12-19 12:00:00   2014
# 11512  2014-12-01 00:00:00   2014
# 12722  2014-02-13 21:24:00   2014
# 18979  2014-09-10 11:08:00   2014
# 21913  2014-05-01 13:00:00   2014
# ...                    ...    ...
# 474713 2014-11-19 12:25:00   2014
# 483431 2014-08-07 20:45:00   2014
# 487237 2014-04-17 18:00:00   2014
# 493148 2014-09-24 13:23:00   2014
# 502702 2014-05-01 00:00:00   2014
#
# [83078 rows x 8 columns]
#         INCIDENT_ID  FIRST_OCCURRENCE_DATE              OFFENSE_TYPE_ID  \
# 730     20186001823   2/19/2015 8:50:00 AM         fraud-identity-theft
# 1153     2016504455    8/9/2015 8:00:00 AM            theft-of-services
# 1905     2015116121    3/1/2015 8:30:00 AM               homicide-other
# 10863    2018427131   1/1/2015 12:00:00 AM                sex-aslt-rape
# 12645    2016587443  10/15/2015 3:00:00 PM     theft-items-from-vehicle
# ...             ...                    ...                          ...
# 500121   2018803906   1/1/2015 12:00:00 AM            sex-aslt-rape-pot
# 501379   2018803619    1/1/2015 8:00:00 AM            sex-aslt-rape-pot
# 501735   2018688738  11/29/2015 8:00:00 AM                   harassment
# 505269   2018805999  10/12/2015 8:00:00 AM                      bribery
# 506934   2018747244   12/1/2015 6:02:00 PM  harassment-sexual-in-nature
#
#              OFFENSE_CATEGORY_ID    GEO_LAT     GEO_LON                date  \
# 730           white-collar-crime  39.750645 -104.981133 2015-02-19 08:50:00
# 1153                     larceny  39.673662 -104.969627 2015-08-09 08:00:00
# 1905                      murder  39.650783 -104.904484 2015-03-01 08:30:00
# 10863             sexual-assault        NaN         NaN 2015-01-01 00:00:00
# 12645   theft-from-motor-vehicle  39.762523 -104.919806 2015-10-15 15:00:00
# ...                          ...        ...         ...                 ...
# 500121            sexual-assault        NaN         NaN 2015-01-01 00:00:00
# 501379            sexual-assault        NaN         NaN 2015-01-01 08:00:00
# 501735           public-disorder  39.739386 -104.963838 2015-11-29 08:00:00
# 505269          all-other-crimes  39.770544 -104.923699 2015-10-12 08:00:00
# 506934           public-disorder  39.727035 -105.048990 2015-12-01 18:02:00
#
#         years
# 730      2015
# 1153     2015
# 1905     2015
# 10863    2015
# 12645    2015
# ...       ...
# 500121   2015
# 501379   2015
# 501735   2015
# 505269   2015
# 506934   2015
#
# [89353 rows x 8 columns]
#         INCIDENT_ID  FIRST_OCCURRENCE_DATE               OFFENSE_TYPE_ID  \
# 0        2016376978  6/15/2016 11:31:00 PM  weapon-unlawful-discharge-of
# 2       20166003953    3/4/2016 8:00:00 PM      theft-items-from-vehicle
# 12       2016340553   5/31/2016 4:54:00 PM                theft-shoplift
# 14       2016236602   4/16/2016 3:25:00 PM                theft-shoplift
# 29       2016398281   6/12/2016 8:00:00 PM          criminal-trespassing
# ...             ...                    ...                           ...
# 498866   2018709546    4/1/2016 6:00:00 AM             sex-aslt-non-rape
# 499278  20185005159   6/1/2016 10:00:00 AM        drug-marijuana-possess
# 501467   2018673419   12/1/2016 8:00:00 AM         sex-aslt-non-rape-pot
# 502525  20185005358   8/26/2016 9:00:00 AM             sex-aslt-non-rape
# 504684  20185004673   10/7/2016 8:00:00 AM      sex-off-fail-to-register
#
#              OFFENSE_CATEGORY_ID    GEO_LAT     GEO_LON                date  \
# 0               all-other-crimes  39.773188 -104.809881 2016-06-15 23:31:00
# 2       theft-from-motor-vehicle  39.663490 -104.957381 2016-03-04 20:00:00
# 12                       larceny  39.689021 -104.942153 2016-05-31 16:54:00
# 14                       larceny  39.699214 -104.902812 2016-04-16 15:25:00
# 29              all-other-crimes  39.789301 -104.883245 2016-06-12 20:00:00
# ...                          ...        ...         ...                 ...
# 498866            sexual-assault        NaN         NaN 2016-04-01 06:00:00
# 499278              drug-alcohol  39.769459 -105.020090 2016-06-01 10:00:00
# 501467            sexual-assault        NaN         NaN 2016-12-01 08:00:00
# 502525            sexual-assault        NaN         NaN 2016-08-26 09:00:00
# 504684          all-other-crimes  39.737154 -104.992313 2016-10-07 08:00:00
#
#         years
# 0        2016
# 2        2016
# 12       2016
# 14       2016
# 29       2016
# ...       ...
# 498866   2016
# 499278   2016
# 501467   2016
# 502525   2016
# 504684   2016
#
# [91394 rows x 8 columns]
#         INCIDENT_ID   FIRST_OCCURRENCE_DATE               OFFENSE_TYPE_ID  \
# 1       20186000994  10/11/2017 12:30:00 PM                   theft-other
# 4        2017411405    6/22/2017 8:53:00 PM                theft-shoplift
# 6       20186001015    6/1/2017 12:15:00 PM      theft-parts-from-vehicle
# 13       2017383968    2/24/2017 4:55:00 PM        theft-of-motor-vehicle
# 15      20176004695    5/28/2017 2:00:00 AM      theft-items-from-vehicle
# ...             ...                     ...                           ...
# 504447  20195003267    7/1/2017 12:00:00 AM                 sex-aslt-rape
# 505396   2017801052   11/29/2017 6:30:00 PM                 sex-aslt-rape
# 505850  20185005180    11/1/2017 8:00:00 AM  sex-aslt-fondle-adult-victim
# 506363   2018779376    12/9/2017 7:00:00 PM                 sex-aslt-rape
# 507276  20186010954  10/17/2017 11:00:00 PM      theft-items-from-vehicle
#
#              OFFENSE_CATEGORY_ID    GEO_LAT     GEO_LON                date  \
# 1                        larceny  39.785649 -104.781434 2017-10-11 12:30:00
# 4                        larceny  39.717107 -104.955370 2017-06-22 20:53:00
# 6       theft-from-motor-vehicle  39.732790 -105.025543 2017-06-01 12:15:00
# 13                    auto-theft  39.754477 -105.023330 2017-02-24 16:55:00
# 15      theft-from-motor-vehicle  39.764565 -105.014275 2017-05-28 02:00:00
# ...                          ...        ...         ...                 ...
# 504447            sexual-assault        NaN         NaN 2017-07-01 00:00:00
# 505396            sexual-assault        NaN         NaN 2017-11-29 18:30:00
# 505850            sexual-assault        NaN         NaN 2017-11-01 08:00:00
# 506363            sexual-assault        NaN         NaN 2017-12-09 19:00:00
# 507276  theft-from-motor-vehicle  39.704978 -104.981918 2017-10-17 23:00:00
#
#         years
# 1        2017
# 4        2017
# 6        2017
# 13       2017
# 15       2017
# ...       ...
# 504447   2017
# 505396   2017
# 505850   2017
# 506363   2017
# 507276   2017
#
# [93176 rows x 8 columns]
#         INCIDENT_ID  FIRST_OCCURRENCE_DATE               OFFENSE_TYPE_ID  \
# 3         201872333   1/30/2018 7:20:00 PM                   theft-other
# 5         201872837  1/31/2018 12:44:00 AM                    traf-other
# 7         201870628   1/30/2018 7:40:00 AM          criminal-trespassing
# 8         201870833   1/30/2018 9:10:00 AM  traffic-accident-hit-and-run
# 9       20186001048  1/31/2018 12:55:00 AM      theft-items-from-vehicle
# ...             ...                    ...                           ...
# 508722   2018836985  12/11/2018 6:06:00 PM                    traf-other
# 508723  20188058998  11/19/2018 4:00:00 PM    theft-fail-return-rent-veh
# 508724   2018848306  12/16/2018 5:37:00 PM              traffic-accident
# 508725   2018831000   12/9/2018 5:21:00 AM                    traf-other
# 508726  20186012081  12/12/2018 4:35:00 PM      theft-parts-from-vehicle
#
#              OFFENSE_CATEGORY_ID    GEO_LAT     GEO_LON                date  \
# 3                        larceny  39.702698 -104.941440 2018-01-30 19:20:00
# 5               all-other-crimes  39.743149 -104.961928 2018-01-31 00:44:00
# 7               all-other-crimes  39.723424 -104.983794 2018-01-30 07:40:00
# 8               traffic-accident  39.736863 -104.991650 2018-01-30 09:10:00
# 9       theft-from-motor-vehicle  39.757627 -105.015451 2018-01-31 00:55:00
# ...                          ...        ...         ...                 ...
# 508722          all-other-crimes  39.739862 -104.948043 2018-12-11 18:06:00
# 508723        white-collar-crime  39.836210 -104.697230 2018-11-19 16:00:00
# 508724          traffic-accident  39.687491 -104.940655 2018-12-16 17:37:00
# 508725          all-other-crimes  39.738855 -105.029758 2018-12-09 05:21:00
# 508726  theft-from-motor-vehicle  39.678211 -104.937077 2018-12-12 16:35:00
#
#         years
# 3        2018
# 5        2018
# 7        2018
# 8        2018
# 9        2018
# ...       ...
# 508722   2018
# 508723   2018
# 508724   2018
# 508725   2018
# 508726   2018
#
# [93420 rows x 8 columns]

# %%
def reformat_datetime(df):
    datetimes = []
    for d,t  in zip(df["date"], df["Time Occurred"]):
#         print(d)
#         print(type(d))
    #     datetime = (datetime.strftime(d, format='%Y-%m-%d') + " " + str(t))
        d = datetime.strptime(str(d), "%Y-%m-%d %H:%M:%S")
        date_time = datetime.strftime(d, format='%Y-%m-%d') + "T" + str((int(t/100))) + ":00:00"
    #     datetime = d + " " + t
        datetimes.append(date_time)
    df["date_time"] = datetimes
    return df

def reformat_datetime(df):
    datetimes = []
    for d in df:
        d = datetime.strftime

# %%
df_years = [data_2014, data_2015, data_2016, data_2017, data_2018]

for i, yr in enumerate(df_years):
    df = reformat_datetime(yr)
    if i == 0:
        data_2014_1 = df.copy()
    elif i ==1:
        data_2015_1 = df.copy()
    elif i ==2:
        data_2016_1 = df.copy()
    elif i ==3:
        data_2017_1 = df.copy()
    elif i ==4:
        data_2018_1 = df.copy()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Time Occurred'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-f5939ee10bff> in <module>
#       2
#       3 for i, yr in enumerate(df_years):
# ----> 4     df = reformat_datetime(yr)
#       5     if i == 0:
#       6         data_2014_1 = df.copy()
#
# <ipython-input-6-dc133e960a9f> in reformat_datetime(df)
#       1 def reformat_datetime(df):
#       2     datetimes = []
# ----> 3     for d,t  in zip(df["date"], df["Time Occurred"]):
#       4 #         print(d)
#       5 #         print(type(d))
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2973             if self.columns.nlevels > 1:
#    2974                 return self._getitem_multilevel(key)
# -> 2975             indexer = self.columns.get_loc(key)
#    2976             if is_integer(indexer):
#    2977                 indexer = [indexer]
#
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
# -> 2892                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2893         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2894         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Time Occurred'
