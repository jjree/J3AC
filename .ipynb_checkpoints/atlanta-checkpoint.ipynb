# %%
# Dependencies
from splinter import Browser
from bs4 import BeautifulSoup as bs
from sqlalchemy import create_engine
import numpy as np
import pandas as pd
import requests
import pymongo
from datetime import datetime
import ast

# %%
file = "data/Atlanta/Atlanta_CRIME_Data.csv"
data1 = pd.read_csv(file)
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data1
# Out:
#         Report Number Report Date  Occur Date  Occur Time Possible Date  \
# 0            90010930    1/1/2009    1/1/2009        1145      1/1/2009
# 1            90011083    1/1/2009    1/1/2009        1330      1/1/2009
# 2            90011208    1/1/2009    1/1/2009        1500      1/1/2009
# 3            90011218    1/1/2009    1/1/2009        1450      1/1/2009
# 4            90011289    1/1/2009    1/1/2009        1600      1/1/2009
# ...               ...         ...         ...         ...           ...
# 317899      183651752  12/31/2018  12/31/2018        1845    12/31/2018
# 317900      183652121  12/31/2018  12/31/2018        2123    12/31/2018
# 317901      183652271  12/31/2018  12/31/2018        2205    12/31/2018
# 317902      183650457  12/31/2018  12/31/2018         500    12/31/2018
# 317903      183651734  12/31/2018  12/26/2018        1300    12/31/2018
#
#         Possible Time   Beat Apartment Office Prefix Apartment Number  \
# 0              1148.0  408.0                     NaN              NaN
# 1              1330.0  506.0                     NaN              NaN
# 2              1520.0  413.0                     NaN              NaN
# 3              1510.0  204.0                     NaN              NaN
# 4              1700.0  408.0                     NaN              NaN
# ...               ...    ...                     ...              ...
# 317899         1930.0  404.0                     NaN              NaN
# 317900         2145.0  307.0                     NaN              NaN
# 317901         2208.0  203.0                     NaN              NaN
# 317902          645.0  301.0                     NaN               11
# 317903         1850.0  208.0                     NaN              NaN
#
#                            Location Shift Occurence Location Type  \
# 0              2841 GREENBRIAR PKWY       Day Watch             8
# 1                    12 BROAD ST SW       Day Watch             9
# 2       3500 MARTIN L KING JR DR SW         Unknown             8
# 3              3393 PEACHTREE RD NE   Evening Watch             8
# 4           2841 GREENBRIAR PKWY SW         Unknown             8
# ...                             ...             ...           ...
# 317899           807 CASCADE AVE SW   Evening Watch           NaN
# 317900         1959 LAKEWOOD AVE SE   Evening Watch            23
# 317901            2020 BOLTON RD NW   Morning Watch            23
# 317902        661 UNIVERSITY AVE SW       Day Watch            26
# 317903     3203 W SHADOWLAWN AVE NE   Morning Watch            20
#
#                 UCR Literal  UCR # IBR Code         Neighborhood NPU  \
# 0       LARCENY-NON VEHICLE    630     2303           Greenbriar   R
# 1       LARCENY-NON VEHICLE    630     2303             Downtown   M
# 2       LARCENY-NON VEHICLE    630     2303           Adamsville   H
# 3       LARCENY-NON VEHICLE    630     2303                Lenox   B
# 4       LARCENY-NON VEHICLE    630     2303           Greenbriar   R
# ...                     ...    ...      ...                  ...  ..
# 317899  LARCENY-NON VEHICLE    630     2303  Cascade Avenue/Road   S
# 317900  LARCENY-NON VEHICLE    630     2303     Lakewood Heights   Y
# 317901  LARCENY-NON VEHICLE    630     2303            Riverside   D
# 317902   BURGLARY-RESIDENCE    521     2204           Adair Park   V
# 317903   BURGLARY-RESIDENCE    521     2204      Buckhead Forest   B
#
#         Latitude  Longitude
# 0       33.68845  -84.49328
# 1       33.75320  -84.39201
# 2       33.75735  -84.50282
# 3       33.84676  -84.36212
# 4       33.68677  -84.49773
# ...          ...        ...
# 317899  33.73323  -84.43795
# 317900  33.70262  -84.38491
# 317901  33.81125  -84.47594
# 317902  33.72227  -84.40929
# 317903  33.84317  -84.37459
#
# [317904 rows x 19 columns]

# %%
# Report Number	Report Date	Occur Date	Occur Time	Possible Date	Possible Time	Beat	
# Apartment Office Prefix	Apartment Number	Location	Shift Occurence	Location Type	
# UCR Literal	UCR #	IBR Code	Neighborhood	NPU	Latitude	Longitude

data = data1[["Report Number", "Occur Date", "Occur Time", "UCR Literal", "Latitude", "Longitude"]].copy()
data.rename(columns={'Latitude':'latitude', 'Longitude':'longitude'}, inplace=True)
data
# Out:
#         Report Number  Occur Date  Occur Time          UCR Literal  latitude  \
# 0            90010930    1/1/2009        1145  LARCENY-NON VEHICLE  33.68845
# 1            90011083    1/1/2009        1330  LARCENY-NON VEHICLE  33.75320
# 2            90011208    1/1/2009        1500  LARCENY-NON VEHICLE  33.75735
# 3            90011218    1/1/2009        1450  LARCENY-NON VEHICLE  33.84676
# 4            90011289    1/1/2009        1600  LARCENY-NON VEHICLE  33.68677
# ...               ...         ...         ...                  ...       ...
# 317899      183651752  12/31/2018        1845  LARCENY-NON VEHICLE  33.73323
# 317900      183652121  12/31/2018        2123  LARCENY-NON VEHICLE  33.70262
# 317901      183652271  12/31/2018        2205  LARCENY-NON VEHICLE  33.81125
# 317902      183650457  12/31/2018         500   BURGLARY-RESIDENCE  33.72227
# 317903      183651734  12/26/2018        1300   BURGLARY-RESIDENCE  33.84317
#
#         longitude
# 0       -84.49328
# 1       -84.39201
# 2       -84.50282
# 3       -84.36212
# 4       -84.49773
# ...           ...
# 317899  -84.43795
# 317900  -84.38491
# 317901  -84.47594
# 317902  -84.40929
# 317903  -84.37459
#
# [317904 rows x 6 columns]

# %%
dates = []
years = []

for date in data["Occur Date"]:
    date = datetime.strptime(date, "%m/%d/%Y")
    dates.append(date)
    years.append(date.year)
    
data["date"] = dates
data["years"] = years
data
# Out:
#         Report Number  Occur Date  Occur Time          UCR Literal  latitude  \
# 0            90010930    1/1/2009        1145  LARCENY-NON VEHICLE  33.68845
# 1            90011083    1/1/2009        1330  LARCENY-NON VEHICLE  33.75320
# 2            90011208    1/1/2009        1500  LARCENY-NON VEHICLE  33.75735
# 3            90011218    1/1/2009        1450  LARCENY-NON VEHICLE  33.84676
# 4            90011289    1/1/2009        1600  LARCENY-NON VEHICLE  33.68677
# ...               ...         ...         ...                  ...       ...
# 317899      183651752  12/31/2018        1845  LARCENY-NON VEHICLE  33.73323
# 317900      183652121  12/31/2018        2123  LARCENY-NON VEHICLE  33.70262
# 317901      183652271  12/31/2018        2205  LARCENY-NON VEHICLE  33.81125
# 317902      183650457  12/31/2018         500   BURGLARY-RESIDENCE  33.72227
# 317903      183651734  12/26/2018        1300   BURGLARY-RESIDENCE  33.84317
#
#         longitude       date  years
# 0       -84.49328 2009-01-01   2009
# 1       -84.39201 2009-01-01   2009
# 2       -84.50282 2009-01-01   2009
# 3       -84.36212 2009-01-01   2009
# 4       -84.49773 2009-01-01   2009
# ...           ...        ...    ...
# 317899  -84.43795 2018-12-31   2018
# 317900  -84.38491 2018-12-31   2018
# 317901  -84.47594 2018-12-31   2018
# 317902  -84.40929 2018-12-31   2018
# 317903  -84.37459 2018-12-26   2018
#
# [317904 rows x 8 columns]

# %%
data_2014 = pd.DataFrame()
data_2015 = pd.DataFrame()
data_2016 = pd.DataFrame()
data_2017 = pd.DataFrame()
data_2018 = pd.DataFrame()

data_2014 = data.loc[data["years"] == 2014]
print(data_2014)
data_2015 = data.loc[data["years"] == 2015]
print(data_2015)
data_2016 = data.loc[data["years"] == 2016]
print(data_2016)
data_2017 = data.loc[data["years"] == 2017]
print(data_2017)
data_2018 = data.loc[data["years"] == 2018]
data_2018
# Out:
#         Report Number  Occur Date  Occur Time          UCR Literal  latitude  \
# 175621      140011254    1/1/2014         100           AUTO THEFT  33.69915
# 175622      140012074    1/1/2014        1940   ROBBERY-PEDESTRIAN  33.75290
# 175623      140010429    1/1/2014         226   ROBBERY-PEDESTRIAN  33.77575
# 175624      140010494    1/1/2014         245          AGG ASSAULT  33.76244
# 175625      140011847    1/1/2014        1750          AGG ASSAULT  33.78554
# ...               ...         ...         ...                  ...       ...
# 248423      161560078    6/4/2014          27  LARCENY-NON VEHICLE  33.75861
# 254034      162242355   8/11/2014        1800   BURGLARY-RESIDENCE  33.75127
# 289911      173352433  11/24/2014        2000  LARCENY-NON VEHICLE  33.84676
# 298767      181011366   11/5/2014        1200  LARCENY-NON VEHICLE  33.81924
# 304065      181750378   6/23/2014        2345  LARCENY-NON VEHICLE  33.84100
#
#         longitude       date  years
# 175621  -84.41819 2014-01-01   2014
# 175622  -84.43904 2014-01-01   2014
# 175623  -84.46804 2014-01-01   2014
# 175624  -84.41272 2014-01-01   2014
# 175625  -84.45441 2014-01-01   2014
# ...           ...        ...    ...
# 248423  -84.38749 2014-06-04   2014
# 254034  -84.41963 2014-08-11   2014
# 289911  -84.36212 2014-11-24   2014
# 298767  -84.35086 2014-11-05   2014
# 304065  -84.38035 2014-06-23   2014
#
# [31120 rows x 8 columns]
#         Report Number  Occur Date  Occur Time           UCR Literal  latitude  \
# 206755      150010872    1/1/2015         540    BURGLARY-RESIDENCE  33.74577
# 206756      150012144    1/1/2015        2002    BURGLARY-RESIDENCE  33.68066
# 206757      150012260    1/1/2015        1630    BURGLARY-RESIDENCE  33.66657
# 206758      150010468    1/1/2015         215           AGG ASSAULT  33.76139
# 206759      150011023    1/1/2015         818           AGG ASSAULT  33.69867
# ...               ...         ...         ...                   ...       ...
# 273036      171142452   4/24/2015        1948   LARCENY-NON VEHICLE  33.79282
# 283249      172511971   12/1/2015           1   LARCENY-NON VEHICLE  33.82554
# 285369      172781147   9/21/2015        1200  LARCENY-FROM VEHICLE  33.68679
# 310274      182611872   9/10/2015        1200   LARCENY-NON VEHICLE  33.72656
# 315035      183291334  11/23/2015        1100   LARCENY-NON VEHICLE  33.69508
#
#         longitude       date  years
# 206755  -84.31650 2015-01-01   2015
# 206756  -84.49371 2015-01-01   2015
# 206757  -84.39138 2015-01-01   2015
# 206758  -84.38406 2015-01-01   2015
# 206759  -84.49750 2015-01-01   2015
# ...           ...        ...    ...
# 273036  -84.39779 2015-04-24   2015
# 283249  -84.38734 2015-12-01   2015
# 285369  -84.54237 2015-09-21   2015
# 310274  -84.38306 2015-09-10   2015
# 315035  -84.50515 2015-11-23   2015
#
# [30060 rows x 8 columns]
#         Report Number Occur Date  Occur Time           UCR Literal  latitude  \
# 236844      160011550   1/1/2016        1420   LARCENY-NON VEHICLE  33.84676
# 236845      160011569   1/1/2016        1449   LARCENY-NON VEHICLE  33.75674
# 236846      160011645   1/1/2016        1530   LARCENY-NON VEHICLE  33.75144
# 236847      160011823   1/1/2016        1515   LARCENY-NON VEHICLE  33.84676
# 236848      160011975   1/1/2016          15   LARCENY-NON VEHICLE  33.75082
# ...               ...        ...         ...                   ...       ...
# 294967      180411672   2/7/2016        1600    BURGLARY-RESIDENCE  33.68387
# 306421      182062483  7/25/2016        2349  LARCENY-FROM VEHICLE  33.80131
# 307945      182280894  8/15/2016        2100  LARCENY-FROM VEHICLE  33.73266
# 313771      183110695   3/1/2016         900   LARCENY-NON VEHICLE  33.84151
# 316353      183461453  12/6/2016        1200   LARCENY-NON VEHICLE  33.83830
#
#         longitude       date  years
# 236844  -84.36212 2016-01-01   2016
# 236845  -84.34619 2016-01-01   2016
# 236846  -84.44382 2016-01-01   2016
# 236847  -84.36212 2016-01-01   2016
# 236848  -84.39623 2016-01-01   2016
# ...           ...        ...    ...
# 294967  -84.50204 2016-02-07   2016
# 306421  -84.42074 2016-07-25   2016
# 307945  -84.41448 2016-08-15   2016
# 313771  -84.42604 2016-03-01   2016
# 316353  -84.42026 2016-12-06   2016
#
# [29005 rows x 8 columns]
#         Report Number  Occur Date  Occur Time           UCR Literal  latitude  \
# 265865      170010079    1/1/2017           0  LARCENY-FROM VEHICLE  33.68990
# 265870      170010712    1/1/2017         130  LARCENY-FROM VEHICLE  33.81038
# 265873      170011070    1/1/2017        1025  LARCENY-FROM VEHICLE  33.74505
# 265876      170011255    1/1/2017        1200  LARCENY-FROM VEHICLE  33.72602
# 265879      170011504    1/1/2017        1500  LARCENY-FROM VEHICLE  33.76341
# ...               ...         ...         ...                   ...       ...
# 309417      182491978   8/26/2017        1400  LARCENY-FROM VEHICLE  33.70271
# 310548      182650909   9/21/2017        2200            AUTO THEFT  33.75785
# 310644      182670372   9/23/2017        1130  LARCENY-FROM VEHICLE  33.75779
# 312824      182980871    5/6/2017        1000   LARCENY-NON VEHICLE  33.70085
# 316778      183510759  12/14/2017           0  LARCENY-FROM VEHICLE  33.75831
#
#         longitude       date  years
# 265865  -84.50584 2017-01-01   2017
# 265870  -84.36122 2017-01-01   2017
# 265873  -84.40523 2017-01-01   2017
# 265876  -84.32324 2017-01-01   2017
# 265879  -84.35289 2017-01-01   2017
# ...           ...        ...    ...
# 309417  -84.47559 2017-08-26   2017
# 310548  -84.35649 2017-09-21   2017
# 310644  -84.36680 2017-09-23   2017
# 312824  -84.42406 2017-05-06   2017
# 316778  -84.34680 2017-12-14   2017
#
# [26380 rows x 8 columns]
#         Report Number  Occur Date  Occur Time           UCR Literal  latitude  \
# 292276      180011286    1/1/2018         330  LARCENY-FROM VEHICLE  33.69811
# 292281      180011390    1/1/2018        1530   LARCENY-NON VEHICLE  33.73604
# 292282      180011692    1/1/2018        1625   LARCENY-NON VEHICLE  33.85182
# 292283      180011735    1/1/2018        1700   LARCENY-NON VEHICLE  33.65722
# 292287      180011167    1/1/2018          30            AUTO THEFT  33.78887
# ...               ...         ...         ...                   ...       ...
# 317899      183651752  12/31/2018        1845   LARCENY-NON VEHICLE  33.73323
# 317900      183652121  12/31/2018        2123   LARCENY-NON VEHICLE  33.70262
# 317901      183652271  12/31/2018        2205   LARCENY-NON VEHICLE  33.81125
# 317902      183650457  12/31/2018         500    BURGLARY-RESIDENCE  33.72227
# 317903      183651734  12/26/2018        1300    BURGLARY-RESIDENCE  33.84317
#
#         longitude       date  years
# 292276  -84.42947 2018-01-01   2018
# 292281  -84.43627 2018-01-01   2018
# 292282  -84.35950 2018-01-01   2018
# 292283  -84.51029 2018-01-01   2018
# 292287  -84.42027 2018-01-01   2018
# ...           ...        ...    ...
# 317899  -84.43795 2018-12-31   2018
# 317900  -84.38491 2018-12-31   2018
# 317901  -84.47594 2018-12-31   2018
# 317902  -84.40929 2018-12-31   2018
# 317903  -84.37459 2018-12-26   2018
#
# [25447 rows x 8 columns]

# %%
def reformat_datetime(df):
    datetimes = []
    for d,t  in zip(df["date"], df["Occur Time"]):
#         print(d)
#         print(type(d))
    #     datetime = (datetime.strftime(d, format='%Y-%m-%d') + " " + str(t))
        d = datetime.strptime(str(d), "%Y-%m-%d %H:%M:%S")
        date_time = datetime.strftime(d, format='%Y-%m-%d') + "T" + str((int(t/100))) + ":00:00"
    #     datetime = d + " " + t
        datetimes.append(date_time)
    df["date_time"] = datetimes
    return df

# def reformat_datetime(df):
#     datetimes = []
#     for d in df["date"]:
#         date_time = datetime.strftime(d, format='%Y-%m-%dT%H:00:00')
#         datetimes.append(date_time)
#     df["date_time"] = datetimes
#     return df

# %%
df_years = [data_2014, data_2015, data_2016, data_2017, data_2018]

for i, yr in enumerate(df_years):
    df = reformat_datetime(yr)
    if i == 0:
        data_2014_1 = df.copy()
    elif i ==1:
        data_2015_1 = df.copy()
    elif i ==2:
        data_2016_1 = df.copy()
    elif i ==3:
        data_2017_1 = df.copy()
    elif i ==4:
        data_2018_1 = df.copy()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-f5939ee10bff> in <module>
#       2
#       3 for i, yr in enumerate(df_years):
# ----> 4     df = reformat_datetime(yr)
#       5     if i == 0:
#       6         data_2014_1 = df.copy()
#
# <ipython-input-9-fee4050c55dd> in reformat_datetime(df)
#       5 #         print(type(d))
#       6     #     datetime = (datetime.strftime(d, format='%Y-%m-%d') + " " + str(t))
# ----> 7         d = datetime.strptime(str(d), "%Y-%m-%d")
#       8         date_time = datetime.strftime(d, format='%Y-%m-%d') + "T" + str((int(t/100))) + ":00:00"
#       9     #     datetime = d + " " + t
#
# /anaconda3/envs/PythonData/lib/python3.6/_strptime.py in _strptime_datetime(cls, data_string, format)
#     563     """Return a class cls instance based on the input string and the
#     564     format string."""
# --> 565     tt, fraction = _strptime(data_string, format)
#     566     tzname, gmtoff = tt[-2:]
#     567     args = tt[:6] + (fraction,)
#
# /anaconda3/envs/PythonData/lib/python3.6/_strptime.py in _strptime(data_string, format)
#     363     if len(data_string) != found.end():
#     364         raise ValueError("unconverted data remains: %s" %
# --> 365                           data_string[found.end():])
#     366
#     367     iso_year = year = None
#
# ValueError: unconverted data remains:  00:00:00

# %% [markdown]
# ----
#
# # Final view of date_time into weather data datetime format

# %%
data_2014_1

# %%
data_2015_1

# %%
data_2016_1

# %%
data_2017_1

# %%
data_2018_1

# %%
# .to_csv(index=False)
data_2014_1.to_csv (r'data/Boston/data_2014.csv', index = None, header=True)
data_2015_1.to_csv (r'data/Boston/data_2015.csv', index = None, header=True)
data_2016_1.to_csv (r'data/Boston/data_2016.csv', index = None, header=True)
data_2017_1.to_csv (r'data/Boston/data_2017.csv', index = None, header=True)
data_2018_1.to_csv (r'data/Boston/data_2018.csv', index = None, header=True)
