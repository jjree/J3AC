# %%
# Dependencies
from splinter import Browser
from bs4 import BeautifulSoup as bs
from sqlalchemy import create_engine
import numpy as np
import pandas as pd
import requests
import pymongo
from datetime import datetime
import ast

# %%
file = "data/Boston/Boston_CRIME_Data.csv"
data1 = pd.read_csv(file)

# %%
# INCIDENT_NUMBER	OFFENSE_CODE	OFFENSE_CODE_GROUP	OFFENSE_DESCRIPTION	DISTRICT	REPORTING_AREA	SHOOTING	
# OCCURRED_ON_DATE	YEAR	MONTH	DAY_OF_WEEK	HOUR	UCR_PART	STREET	Lat	Long	Location

data = data1[["INCIDENT_NUMBER", "OCCURRED_ON_DATE", "OFFENSE_DESCRIPTION", "Lat", "Long"]].copy()
data.rename(columns={'Lat':'latitude', 'Long':'longitude'}, inplace=True)
data
# Out:
#        INCIDENT_NUMBER     OCCURRED_ON_DATE              OFFENSE_DESCRIPTION  \
# 0           I192070092  2019-09-02 21:42:00               INVESTIGATE PERSON
# 1           I192070085  2019-09-02 21:36:00   ASSAULT - AGGRAVATED - BATTERY
# 2           I192070082  2019-09-02 21:35:00    SICK/INJURED/MEDICAL - PERSON
# 3           I192070081  2019-09-02 21:30:00                      TRESPASSING
# 4           I192070078  2019-09-02 21:11:00  VAL - OPERATING WITHOUT LICENSE
# ...                ...                  ...                              ...
# 418597   I020691165-00  2019-05-23 08:00:00                   WARRANT ARREST
# 418598   I020674147-00  2019-05-23 08:00:00                   WARRANT ARREST
# 418599   I020669075-00  2019-05-23 08:00:00                   WARRANT ARREST
# 418600   I020662996-00  2019-05-23 08:56:00                   WARRANT ARREST
# 418601   I010370257-00  2016-05-31 19:35:00                   WARRANT ARREST
#
#          latitude  longitude
# 0       42.311763 -71.063242
# 1       42.286710 -71.108229
# 2             NaN        NaN
# 3       42.356741 -71.057947
# 4       42.320711 -71.086023
# ...           ...        ...
# 418597  42.361839 -71.059765
# 418598  42.361839 -71.059765
# 418599  42.361839 -71.059765
# 418600  42.361839 -71.059765
# 418601  42.302333 -71.111565
#
# [418602 rows x 5 columns]

# %%
dates = []
years = []

for date in data["OCCURRED_ON_DATE"]:
    date = datetime.strptime(date, "%Y-%m-%d %H:%M:%S")
    dates.append(date)
    years.append(date.year)
    
data["date"] = dates
data["years"] = years
data
# Out:
#        INCIDENT_NUMBER     OCCURRED_ON_DATE              OFFENSE_DESCRIPTION  \
# 0           I192070092  2019-09-02 21:42:00               INVESTIGATE PERSON
# 1           I192070085  2019-09-02 21:36:00   ASSAULT - AGGRAVATED - BATTERY
# 2           I192070082  2019-09-02 21:35:00    SICK/INJURED/MEDICAL - PERSON
# 3           I192070081  2019-09-02 21:30:00                      TRESPASSING
# 4           I192070078  2019-09-02 21:11:00  VAL - OPERATING WITHOUT LICENSE
# ...                ...                  ...                              ...
# 418597   I020691165-00  2019-05-23 08:00:00                   WARRANT ARREST
# 418598   I020674147-00  2019-05-23 08:00:00                   WARRANT ARREST
# 418599   I020669075-00  2019-05-23 08:00:00                   WARRANT ARREST
# 418600   I020662996-00  2019-05-23 08:56:00                   WARRANT ARREST
# 418601   I010370257-00  2016-05-31 19:35:00                   WARRANT ARREST
#
#          latitude  longitude                date  years
# 0       42.311763 -71.063242 2019-09-02 21:42:00   2019
# 1       42.286710 -71.108229 2019-09-02 21:36:00   2019
# 2             NaN        NaN 2019-09-02 21:35:00   2019
# 3       42.356741 -71.057947 2019-09-02 21:30:00   2019
# 4       42.320711 -71.086023 2019-09-02 21:11:00   2019
# ...           ...        ...                 ...    ...
# 418597  42.361839 -71.059765 2019-05-23 08:00:00   2019
# 418598  42.361839 -71.059765 2019-05-23 08:00:00   2019
# 418599  42.361839 -71.059765 2019-05-23 08:00:00   2019
# 418600  42.361839 -71.059765 2019-05-23 08:56:00   2019
# 418601  42.302333 -71.111565 2016-05-31 19:35:00   2016
#
# [418602 rows x 7 columns]

# %%
print(type(data["years"][0]))
data

# %%
data_2014 = pd.DataFrame()
data_2015 = pd.DataFrame()
data_2016 = pd.DataFrame()
data_2017 = pd.DataFrame()
data_2018 = pd.DataFrame()

data_2014 = data.loc[data["years"] == 2014]
print(data_2014)
data_2015 = data.loc[data["years"] == 2015]
print(data_2015)
data_2016 = data.loc[data["years"] == 2016]
print(data_2016)
data_2017 = data.loc[data["years"] == 2017]
print(data_2017)
data_2018 = data.loc[data["years"] == 2018]
data_2018
# Out:
# Empty DataFrame
# Columns: [INCIDENT_NUMBER, OCCURRED_ON_DATE, OFFENSE_DESCRIPTION, latitude, longitude, date, years]
# Index: []
#        INCIDENT_NUMBER     OCCURRED_ON_DATE  \
# 1586        I192068249  2015-08-28 10:20:00
# 7377        I192061894  2015-08-20 00:00:00
# 29147       I192038828  2015-11-02 12:24:00
# 57561       I192008877  2015-07-31 10:00:00
# 79113       I182090828  2015-12-01 12:00:00
# ...                ...                  ...
# 418575   I080542626-00  2015-08-12 12:00:00
# 418576   I080542626-00  2015-08-12 12:00:00
# 418577   I080542626-00  2015-08-12 12:00:00
# 418593   I030217815-08  2015-07-09 13:38:00
# 418594   I030217815-08  2015-07-09 13:38:00
#
#                                    OFFENSE_DESCRIPTION   latitude  longitude  \
# 1586                         THREATS TO DO BODILY HARM  42.330119 -71.084251
# 7377                   FRAUD - CREDIT CARD / ATM FRAUD  42.300605 -71.061268
# 29147                            FRAUD - IMPERSONATION  42.334288 -71.072395
# 57561                            FRAUD - IMPERSONATION  42.237009 -71.129566
# 79113                  FRAUD - FALSE PRETENSE / SCHEME  42.342432 -71.072258
# ...                                                ...        ...        ...
# 418575  DRUGS - POSS CLASS B - INTENT TO MFR DIST DISP  42.352312 -71.063705
# 418576  DRUGS - POSS CLASS B - INTENT TO MFR DIST DISP  42.352312 -71.063705
# 418577                                  WARRANT ARREST  42.352312 -71.063705
# 418593                                  WARRANT ARREST  42.255926 -71.123172
# 418594             MURDER, NON-NEGLIGIENT MANSLAUGHTER  42.255926 -71.123172
#
#                       date  years
# 1586   2015-08-28 10:20:00   2015
# 7377   2015-08-20 00:00:00   2015
# 29147  2015-11-02 12:24:00   2015
# 57561  2015-07-31 10:00:00   2015
# 79113  2015-12-01 12:00:00   2015
# ...                    ...    ...
# 418575 2015-08-12 12:00:00   2015
DRUGS - POSS CLASS A - INTENT TO MFR DIST DISP  42.330013 -71.091179
#
#                       date  years
# 341    2017-12-10 20:00:00   2017
# 342    2017-12-10 20:00:00   2017
# 386    2017-03-19 17:00:00   2017
# 387    2017-03-19 17:00:00   2017
# 534    2017-09-12 15:00:00   2017
# ...                    ...    ...
# 418527 2017-01-20 02:00:00   2017
# 418528 2017-01-20 02:00:00   2017
# 418529 2017-01-20 02:00:00   2017
# 418530 2017-01-20 02:00:00   2017
# 418531 2017-01-20 02:00:00   2017
#
# [101327 rows x 7 columns]
#        INCIDENT_NUMBER     OCCURRED_ON_DATE  \
# 970         I192068943  2018-02-28 00:00:00
# 1326        I192068538  2018-01-01 00:00:00
# 1469        I192068378  2018-04-10 17:04:00
# 1612        I192068216  2018-08-28 08:23:00
# 1863        I192067941  2018-12-21 13:52:00
# ...                ...                  ...
# 418587   I070720870-00  2018-12-13 00:00:00
# 418588   I070720870-00  2018-12-13 00:00:00
# 418589   I060168073-00  2018-01-27 14:01:00
# 418590   I060168073-00  2018-01-27 14:01:00
# 418591   I060168073-00  2018-01-27 14:01:00
#
#                                 OFFENSE_DESCRIPTION   latitude  longitude  \
# 970                                    FRAUD - WIRE  42.370818 -71.039291
# 1326                          FRAUD - IMPERSONATION  42.349780 -71.134230
# 1469                             LARCENY ALL OTHERS  42.318352 -71.075217
# 1612                                PROPERTY - LOST  42.287017 -71.077065
# 1863                                     HARASSMENT  42.286769 -71.053186
# ...                                             ...        ...        ...
# 418587                            ASSAULT & BATTERY  42.309563 -71.089902
# 418588                            ASSAULT & BATTERY  42.309563 -71.089902
# 418589                               WARRANT ARREST  42.322838 -71.100967
# 418590  DRUGS - POSS CLASS D - INTENT MFR DIST DISP  42.322838 -71.100967
# 418591  DRUGS - POSS CLASS D - INTENT MFR DIST DISP  42.322838 -71.100967
#
#                       date  years
# 970    2018-02-28 00:00:00   2018
# 1326   2018-01-01 00:00:00   2018
# 1469   2018-04-10 17:04:00   2018
# 1612   2018-08-28 08:23:00   2018
# 1863   2018-12-21 13:52:00   2018
# ...                    ...    ...
# 418587 2018-12-13 00:00:00   2018
# 418588 2018-12-13 00:00:00   2018
# 418589 2018-01-27 14:01:00   2018
# 418590 2018-01-27 14:01:00   2018
# 418591 2018-01-27 14:01:00   2018
#
# [98822 rows x 7 columns]

# %%
# def reformat_datetime(df):
#     datetimes = []
#     for d,t  in zip(df["date"], df["Time Occurred"]):
# #         print(d)
# #         print(type(d))
#     #     datetime = (datetime.strftime(d, format='%Y-%m-%d') + " " + str(t))
#         d = datetime.strptime(str(d), "%Y-%m-%d %H:%M:%S")
#         date_time = datetime.strftime(d, format='%Y-%m-%d') + "T" + str((int(t/100))) + ":00:00"
#     #     datetime = d + " " + t
#         datetimes.append(date_time)
#     df["date_time"] = datetimes
#     return df

def reformat_datetime(df):
    datetimes = []
    for d in df["date"]:
        date_time = datetime.strftime(d, format='%Y-%m-%dT%H:00:00')
        datetimes.append(date_time)
    df["date_time"] = datetimes
    return df

# %%
df_years = [data_2014, data_2015, data_2016, data_2017, data_2018]

for i, yr in enumerate(df_years):
    df = reformat_datetime(yr)
    if i == 0:
        data_2014_1 = df.copy()
    elif i ==1:
        data_2015_1 = df.copy()
    elif i ==2:
        data_2016_1 = df.copy()
    elif i ==3:
        data_2017_1 = df.copy()
    elif i ==4:
        data_2018_1 = df.copy()
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
#
DRUGS - POSS CLASS A - INTENT TO MFR DIST DISP  42.330013 -71.091179
#
#                       date  years            date_time
# 341    2017-12-10 20:00:00   2017  2017-12-10T20:00:00
# 342    2017-12-10 20:00:00   2017  2017-12-10T20:00:00
# 386    2017-03-19 17:00:00   2017  2017-03-19T17:00:00
# 387    2017-03-19 17:00:00   2017  2017-03-19T17:00:00
# 534    2017-09-12 15:00:00   2017  2017-09-12T15:00:00
# ...                    ...    ...                  ...
# 418527 2017-01-20 02:00:00   2017  2017-01-20T02:00:00
# 418528 2017-01-20 02:00:00   2017  2017-01-20T02:00:00
# 418529 2017-01-20 02:00:00   2017  2017-01-20T02:00:00
# 418530 2017-01-20 02:00:00   2017  2017-01-20T02:00:00
# 418531 2017-01-20 02:00:00   2017  2017-01-20T02:00:00
#
# [101327 rows x 8 columns]

# %%
data_2018_1
# Out:
#        INCIDENT_NUMBER     OCCURRED_ON_DATE  \
# 970         I192068943  2018-02-28 00:00:00
# 1326        I192068538  2018-01-01 00:00:00
# 1469        I192068378  2018-04-10 17:04:00
# 1612        I192068216  2018-08-28 08:23:00
# 1863        I192067941  2018-12-21 13:52:00
# ...                ...                  ...
# 418587   I070720870-00  2018-12-13 00:00:00
# 418588   I070720870-00  2018-12-13 00:00:00
# 418589   I060168073-00  2018-01-27 14:01:00
# 418590   I060168073-00  2018-01-27 14:01:00
# 418591   I060168073-00  2018-01-27 14:01:00
#
#                                 OFFENSE_DESCRIPTION   latitude  longitude  \
# 970                                    FRAUD - WIRE  42.370818 -71.039291
# 1326                          FRAUD - IMPERSONATION  42.349780 -71.134230
# 1469                             LARCENY ALL OTHERS  42.318352 -71.075217
# 1612                                PROPERTY - LOST  42.287017 -71.077065
# 1863                                     HARASSMENT  42.286769 -71.053186
# ...                                             ...        ...        ...
# 418587                            ASSAULT & BATTERY  42.309563 -71.089902
# 418588                            ASSAULT & BATTERY  42.309563 -71.089902
# 418589                               WARRANT ARREST  42.322838 -71.100967
# 418590  DRUGS - POSS CLASS D - INTENT MFR DIST DISP  42.322838 -71.100967
# 418591  DRUGS - POSS CLASS D - INTENT MFR DIST DISP  42.322838 -71.100967
#
#                       date  years            date_time
# 970    2018-02-28 00:00:00   2018  2018-02-28T00:00:00
# 1326   2018-01-01 00:00:00   2018  2018-01-01T00:00:00
# 1469   2018-04-10 17:04:00   2018  2018-04-10T17:00:00
# 1612   2018-08-28 08:23:00   2018  2018-08-28T08:00:00
# 1863   2018-12-21 13:52:00   2018  2018-12-21T13:00:00
# ...                    ...    ...                  ...
# 418587 2018-12-13 00:00:00   2018  2018-12-13T00:00:00
# 418588 2018-12-13 00:00:00   2018  2018-12-13T00:00:00
# 418589 2018-01-27 14:01:00   2018  2018-01-27T14:00:00
# 418590 2018-01-27 14:01:00   2018  2018-01-27T14:00:00
# 418591 2018-01-27 14:01:00   2018  2018-01-27T14:00:00
#
# [98822 rows x 8 columns]

# %%
# .to_csv(index=False)
data_2014_1.to_csv (r'data/Boston/data_2014.csv', index = None, header=True)
data_2015_1.to_csv (r'data/Boston/data_2015.csv', index = None, header=True)
data_2016_1.to_csv (r'data/Boston/data_2016.csv', index = None, header=True)
data_2017_1.to_csv (r'data/Boston/data_2017.csv', index = None, header=True)
data_2018_1.to_csv (r'data/Boston/data_2018.csv', index = None, header=True)
